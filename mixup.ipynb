# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # 使用指定GPU
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder, CIFAR100
from torchtoolbox.tools import summary
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
from collections import OrderedDict


def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)


device = get_default_device()
print('检查GPU是否可用：',device)
# !nvidia-smi
# Out:
# 检查GPU是否可用： cuda
# Sun May  8 19:43:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 32%   40C    P8    40W / 350W |   6437MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 35%   38C    P8    33W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 从kaggle下载数据集CIFAR-100数据集

# %%
import opendatasets as od

od.download('https://www.kaggle.com/c/2021-ai-training/data')
# Out:
# Skipping, found downloaded files in "./2021-ai-training" (use force=True to force download)

# %%
data_dir = './2021-ai-training/CIFAR100'
classes = os.listdir(data_dir + "/TRAIN")
print(classes)
# Out:
# ['chair', 'rocket', 'fox', 'poppy', 'apple', 'trout', 'palm_tree', 'seal', 'bridge', 'kangaroo', 'aquarium_fish', 'dolphin', 'beetle', 'pickup_truck', 'plain', 'can', 'snake', 'squirrel', 'skunk', 'lizard', 'bicycle', 'bottle', 'caterpillar', 'flatfish', 'shrew', 'lion', 'skyscraper', 'leopard', 'mountain', 'orange', 'porcupine', 'chimpanzee', 'motorcycle', 'hamster', 'otter', 'bee', 'mouse', 'worm', 'mushroom', 'cockroach', 'crocodile', 'bowl', 'willow_tree', 'lobster', 'train', 'road', 'tank', 'rose', 'streetcar', 'camel', 'lawn_mower', 'table', 'oak_tree', 'tiger', 'bear', 'woman', 'pine_tree', 'dinosaur', 'bus', 'bed', 'butterfly', 'man', 'shark', 'sunflower', 'raccoon', 'wardrobe', 'rabbit', 'crab', 'beaver', 'lamp', 'cattle', 'orchid', 'ray', 'elephant', 'clock', 'baby', 'boy', 'castle', 'cup', 'forest', 'possum', 'sweet_pepper', 'telephone', 'maple_tree', 'tulip', 'girl', 'pear', 'television', 'whale', 'spider', 'snail', 'wolf', 'house', 'keyboard', 'couch', 'cloud', 'turtle', 'tractor', 'sea', 'plate']

# %%
# !nvidia-smi
# Out:
# Sun May  8 03:29:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 88%   60C    P8    52W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 35%   40C    P8    32W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
'''
数据预处理
'''

method='null'


class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """

    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            # (x,y)表示方形补丁的中心位置
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img


normalize = tt.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
train_tfms = tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
])

if method=='cutout':
    #train_tfms.append(Cutout(n_holes=1, length=16))
    tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
        Cutout(n_holes=1, length=8),
])
    
valid_tfms = tt.Compose([
#         tt.Resize(256),  # transforms.Scale(256)
#         tt.CenterCrop(224),
        tt.ToTensor(),
        normalize,
])

# 对数据做标准化
# 训练集与测试集
train_ds = ImageFolder(root=data_dir+"/TRAIN",transform=train_tfms)
valid_ds = ImageFolder(root=data_dir+"/TEST",transform=valid_tfms)

# 用pytorh读取数据
BATCH_SIZE=128
train_dl = DataLoader(train_ds,batch_size=BATCH_SIZE,shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds,batch_size=100, shuffle=False, num_workers=2)

#用CGPU读取数据集
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
    
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %%
'''
数据增强方法
'''
def mixup_data(x, y, alpha=1, device=torch.device("cuda")):
    """Returns mixed inputs, pairs of targets, and lambda"""
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size)
    index = index.to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


# def mixup_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)



def cutmix_data(x, y, alpha=1.0, device=torch.device("cuda")):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    rand_index = torch.randperm(x.size()[0]).to(device)
    y_a = y
    y_b = y[rand_index]
    bbx1, bby1, bbx2, bby2 = _rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[rand_index, :, bbx1:bbx2, bby1:bby2]
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))
    return x, y_a, y_b, lam


# def cutmix_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)


def _rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
'''
DenseNet模型
'''
class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu1', nn.ReLU(inplace=True)),
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                        growth_rate, kernel_size=1, stride=1, bias=False)),
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu2', nn.ReLU(inplace=True)),
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                        kernel_size=3, stride=1, padding=1, bias=False)),
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = super(_DenseLayer, self).forward(x)
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)


class _DenseBlock(nn.Sequential):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(num_input_features + i * growth_rate, growth_rate, bn_size, drop_rate)
            self.add_module('denselayer%d' % (i + 1), layer)


class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))


class ImageClassificationBase(nn.Module):
    def training_step(self,batch,method):
        '''
        这里更改方法
        '''
        if method=='null' or method=='cutout':
            images,labels = batch
            out = self(images)
            loss = F.cross_entropy(out,labels)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        elif method=='mixup':
            images,labels = batch
            inputs, targets_a, targets_b, lam = mixup_data(images, labels)
            out = self(inputs)
            loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
        elif method=='cutmix':
            images,labels = batch
            r = np.random.rand(1)
            cutmix_prob=0.5
            if r < cutmix_prob:
                inputs, targets_a, targets_b, lam = cutmix_data(images, labels)
                out = self(inputs)
                loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
            else:
                out = self(images)
                loss = F.cross_entropy(out,labels)
        return loss
    
    def validation_step(self,batch):
        images,labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {'val_loss': loss.detach(), 'val_acc': acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies

        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))
        
        

class DenseNet_Cifar(ImageClassificationBase):
    def __init__(self, growth_rate=12, block_config=(16, 16, 16),
                 num_init_features=24, bn_size=4, drop_rate=0, num_classes=10):

        super(DenseNet_Cifar, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=3, stride=1, padding=1, bias=False)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(num_layers=num_layers, num_input_features=num_features,
                                bn_size=bn_size, growth_rate=growth_rate, drop_rate=drop_rate)
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features, num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)
        
        # initialize conv and bn parameters
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.avg_pool2d(out, kernel_size=8, stride=1).view(features.size(0), -1)
        out = self.classifier(out)
        return out


def densenet_BC_cifar(depth, k, **kwargs):
    N = (depth - 4) // 6
    model = DenseNet_Cifar(growth_rate=k, block_config=[N, N, N], num_init_features=2*k, **kwargs)
    return model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

def adjust_learning_rate(optimizer, epoch):
    if epoch < 75:
        lrr = lr
    elif epoch < 112:
        lrr = lr * 0.1
    else:
        lrr = lr * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lrr

# %%
'''
训练
'''
import math
#调节depth可以调节层数
model = densenet_BC_cifar(depth=100, k=12, num_classes=100)
model = to_device(model,device)

epochs=200
lr=0.1
momentum=0.9
weight_decay=1e-4
optimizer = torch.optim.SGD(model.parameters(), lr, momentum=momentum, weight_decay=weight_decay)

def Train (epochs,train_dl,valid_dl,model,optimizer,method):
    torch.cuda.empty_cache()
    
    history = []
        
    for epoch in range(epochs):
        adjust_learning_rate(optimizer, epoch)
        model.train()
        train_loss = []
        lrs = []
        
        for batch in train_dl:
            loss = model.training_step(batch,method)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            train_loss.append(loss)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lrs.append(get_lr(optimizer))

    
        result = evaluate(model,valid_dl)
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["lrs"] = lrs
        
        model.epoch_end(epoch,result)
        history.append(result)
        
    return history
            

@torch.no_grad()
def evaluate(model,valid_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in valid_dl]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %% [markdown]
# # MixUp

# %%
print('mixup训练过程：')
history_mixup = []
history_mixup += Train(epochs=epochs,train_dl=train_dl,valid_dl=valid_dl,model=model,optimizer=optimizer,method='mixup')
torch.save(model.state_dict(),'model_mixup.pt')
# Out:
# mixup训练过程：
# Epoch [0], last_lr: 0.10000, train_loss: 4.2451, val_loss: 3.7690, val_acc: 0.1186
# Epoch [1], last_lr: 0.10000, train_loss: 3.9182, val_loss: 3.4902, val_acc: 0.1571
# Epoch [2], last_lr: 0.10000, train_loss: 3.6728, val_loss: 3.0527, val_acc: 0.2363
# Epoch [3], last_lr: 0.10000, train_loss: 3.4733, val_loss: 2.7657, val_acc: 0.2982
# Epoch [4], last_lr: 0.10000, train_loss: 3.3364, val_loss: 2.6784, val_acc: 0.3110
# Epoch [5], last_lr: 0.10000, train_loss: 3.2036, val_loss: 2.4049, val_acc: 0.3698
# Epoch [6], last_lr: 0.10000, train_loss: 3.1621, val_loss: 2.3146, val_acc: 0.4011
# Epoch [7], last_lr: 0.10000, train_loss: 3.0754, val_loss: 2.1019, val_acc: 0.4440
# Epoch [8], last_lr: 0.10000, train_loss: 2.9874, val_loss: 2.1109, val_acc: 0.4491
# Epoch [9], last_lr: 0.10000, train_loss: 2.9219, val_loss: 2.0622, val_acc: 0.4562
# Epoch [10], last_lr: 0.10000, train_loss: 2.9111, val_loss: 2.0184, val_acc: 0.4719
# Epoch [11], last_lr: 0.10000, train_loss: 2.8398, val_loss: 1.8829, val_acc: 0.5042
# Epoch [12], last_lr: 0.10000, train_loss: 2.7467, val_loss: 1.9425, val_acc: 0.4943
# Epoch [13], last_lr: 0.10000, train_loss: 2.8016, val_loss: 1.7700, val_acc: 0.5248
# Epoch [14], last_lr: 0.10000, train_loss: 2.7065, val_loss: 1.7357, val_acc: 0.5319
# Epoch [15], last_lr: 0.10000, train_loss: 2.6966, val_loss: 1.7610, val_acc: 0.5375
# Epoch [16], last_lr: 0.10000, train_loss: 2.6980, val_loss: 1.7283, val_acc: 0.5429
# Epoch [17], last_lr: 0.10000, train_loss: 2.6106, val_loss: 1.8115, val_acc: 0.5371
# Epoch [18], last_lr: 0.10000, train_loss: 2.5832, val_loss: 1.9449, val_acc: 0.5017
# Epoch [19], last_lr: 0.10000, train_loss: 2.5826, val_loss: 1.6708, val_acc: 0.5596
# Epoch [20], last_lr: 0.10000, train_loss: 2.5413, val_loss: 1.6162, val_acc: 0.5663
# Epoch [21], last_lr: 0.10000, train_loss: 2.5826, val_loss: 1.5820, val_acc: 0.5895
# Epoch [22], last_lr: 0.10000, train_loss: 2.5499, val_loss: 1.7487, val_acc: 0.5599
# Epoch [23], last_lr: 0.10000, train_loss: 2.5997, val_loss: 1.6096, val_acc: 0.5742
# Epoch [24], last_lr: 0.10000, train_loss: 2.5108, val_loss: 1.5957, val_acc: 0.5874
# Epoch [25], last_lr: 0.10000, train_loss: 2.5400, val_loss: 1.6690, val_acc: 0.5583
# Epoch [26], last_lr: 0.10000, train_loss: 2.5410, val_loss: 1.4945, val_acc: 0.6050
# Epoch [27], last_lr: 0.10000, train_loss: 2.4985, val_loss: 1.5397, val_acc: 0.5866
# Epoch [28], last_lr: 0.10000, train_loss: 2.4503, val_loss: 1.5418, val_acc: 0.6005
# Epoch [29], last_lr: 0.10000, train_loss: 2.4493, val_loss: 1.5953, val_acc: 0.5776
# Epoch [30], last_lr: 0.10000, train_loss: 2.5262, val_loss: 1.5276, val_acc: 0.6053
# Epoch [31], last_lr: 0.10000, train_loss: 2.4369, val_loss: 1.6570, val_acc: 0.5703
# Epoch [32], last_lr: 0.10000, train_loss: 2.4665, val_loss: 1.5733, val_acc: 0.5871
# Epoch [33], last_lr: 0.10000, train_loss: 2.4982, val_loss: 1.4482, val_acc: 0.6149
# Epoch [34], last_lr: 0.10000, train_loss: 2.4752, val_loss: 1.5939, val_acc: 0.5922
# Epoch [35], last_lr: 0.10000, train_loss: 2.4439, val_loss: 1.5347, val_acc: 0.5952
# Epoch [36], last_lr: 0.10000, train_loss: 2.4611, val_loss: 1.4161, val_acc: 0.6225
# Epoch [37], last_lr: 0.10000, train_loss: 2.4066, val_loss: 1.5081, val_acc: 0.6167
# Epoch [38], last_lr: 0.10000, train_loss: 2.4803, val_loss: 1.5199, val_acc: 0.6069
# Epoch [39], last_lr: 0.10000, train_loss: 2.3583, val_loss: 1.4414, val_acc: 0.6180
# Epoch [40], last_lr: 0.10000, train_loss: 2.3874, val_loss: 1.5268, val_acc: 0.6070
# Epoch [41], last_lr: 0.10000, train_loss: 2.3473, val_loss: 1.4195, val_acc: 0.6203
# Epoch [42], last_lr: 0.10000, train_loss: 2.3812, val_loss: 1.5065, val_acc: 0.6137
# Epoch [43], last_lr: 0.10000, train_loss: 2.3754, val_loss: 1.3543, val_acc: 0.6331
# Epoch [44], last_lr: 0.10000, train_loss: 2.3565, val_loss: 1.5106, val_acc: 0.6080
# Epoch [45], last_lr: 0.10000, train_loss: 2.4219, val_loss: 1.4484, val_acc: 0.6244
# Epoch [46], last_lr: 0.10000, train_loss: 2.3401, val_loss: 1.4945, val_acc: 0.6082
# Epoch [47], last_lr: 0.10000, train_loss: 2.3421, val_loss: 1.5186, val_acc: 0.6227
# Epoch [48], last_lr: 0.10000, train_loss: 2.3300, val_loss: 1.5083, val_acc: 0.6100
# Epoch [49], last_lr: 0.10000, train_loss: 2.3934, val_loss: 1.4114, val_acc: 0.6298
# Epoch [50], last_lr: 0.10000, train_loss: 2.3323, val_loss: 1.4788, val_acc: 0.6171
# Epoch [51], last_lr: 0.10000, train_loss: 2.3378, val_loss: 1.3769, val_acc: 0.6393
# Epoch [52], last_lr: 0.10000, train_loss: 2.2999, val_loss: 1.4951, val_acc: 0.6173
# Epoch [53], last_lr: 0.10000, train_loss: 2.3356, val_loss: 1.5311, val_acc: 0.6045
# Epoch [54], last_lr: 0.10000, train_loss: 2.3191, val_loss: 1.3629, val_acc: 0.6468
# Epoch [55], last_lr: 0.10000, train_loss: 2.2971, val_loss: 1.3766, val_acc: 0.6357
# Epoch [56], last_lr: 0.10000, train_loss: 2.3087, val_loss: 1.3063, val_acc: 0.6476
# Epoch [57], last_lr: 0.10000, train_loss: 2.3339, val_loss: 1.4354, val_acc: 0.6280
# Epoch [58], last_lr: 0.10000, train_loss: 2.3146, val_loss: 1.3070, val_acc: 0.6556
# Epoch [59], last_lr: 0.10000, train_loss: 2.3166, val_loss: 1.4464, val_acc: 0.6281
# Epoch [60], last_lr: 0.10000, train_loss: 2.2836, val_loss: 1.3486, val_acc: 0.6448
# Epoch [61], last_lr: 0.10000, train_loss: 2.2776, val_loss: 1.4558, val_acc: 0.6274
# Epoch [62], last_lr: 0.10000, train_loss: 2.3416, val_loss: 1.3795, val_acc: 0.6528
# Epoch [63], last_lr: 0.10000, train_loss: 2.3187, val_loss: 1.4403, val_acc: 0.6363
# Epoch [64], last_lr: 0.10000, train_loss: 2.2554, val_loss: 1.3633, val_acc: 0.6579
# Epoch [65], last_lr: 0.10000, train_loss: 2.3017, val_loss: 1.3930, val_acc: 0.6433
# Epoch [66], last_lr: 0.10000, train_loss: 2.2660, val_loss: 1.3398, val_acc: 0.6536
# Epoch [67], last_lr: 0.10000, train_loss: 2.2337, val_loss: 1.3778, val_acc: 0.6454
# Epoch [68], last_lr: 0.10000, train_loss: 2.3168, val_loss: 1.3515, val_acc: 0.6492
# Epoch [69], last_lr: 0.10000, train_loss: 2.2728, val_loss: 1.2352, val_acc: 0.6710
# Epoch [70], last_lr: 0.10000, train_loss: 2.2614, val_loss: 1.4315, val_acc: 0.6393
# Epoch [71], last_lr: 0.10000, train_loss: 2.2436, val_loss: 1.4457, val_acc: 0.6364
# Epoch [72], last_lr: 0.10000, train_loss: 2.2962, val_loss: 1.3208, val_acc: 0.6520
# Epoch [73], last_lr: 0.10000, train_loss: 2.2765, val_loss: 1.4623, val_acc: 0.6274
# Epoch [74], last_lr: 0.10000, train_loss: 2.2988, val_loss: 1.4675, val_acc: 0.6374
# Epoch [75], last_lr: 0.01000, train_loss: 2.0523, val_loss: 1.0759, val_acc: 0.7293
# Epoch [76], last_lr: 0.01000, train_loss: 2.0211, val_loss: 1.0150, val_acc: 0.7375
# Epoch [77], last_lr: 0.01000, train_loss: 1.9913, val_loss: 1.0220, val_acc: 0.7401
# Epoch [78], last_lr: 0.01000, train_loss: 1.9637, val_loss: 0.9969, val_acc: 0.7455
# Epoch [79], last_lr: 0.01000, train_loss: 2.0026, val_loss: 1.0749, val_acc: 0.7343
# Epoch [80], last_lr: 0.01000, train_loss: 1.9173, val_loss: 0.9875, val_acc: 0.7463
# Epoch [81], last_lr: 0.01000, train_loss: 1.9382, val_loss: 1.0327, val_acc: 0.7409
# Epoch [82], last_lr: 0.01000, train_loss: 1.9598, val_loss: 1.0645, val_acc: 0.7408
# Epoch [83], last_lr: 0.01000, train_loss: 1.9430, val_loss: 1.0123, val_acc: 0.7470
# Epoch [84], last_lr: 0.01000, train_loss: 1.9382, val_loss: 1.0043, val_acc: 0.7490
# Epoch [85], last_lr: 0.01000, train_loss: 1.9536, val_loss: 1.0159, val_acc: 0.7438
# Epoch [86], last_lr: 0.01000, train_loss: 1.9310, val_loss: 1.0288, val_acc: 0.7435
# Epoch [87], last_lr: 0.01000, train_loss: 1.9278, val_loss: 0.9875, val_acc: 0.7488
# Epoch [88], last_lr: 0.01000, train_loss: 1.9495, val_loss: 0.9630, val_acc: 0.7537
# Epoch [89], last_lr: 0.01000, train_loss: 1.9292, val_loss: 0.9930, val_acc: 0.7482
# Epoch [90], last_lr: 0.01000, train_loss: 1.9894, val_loss: 1.0818, val_acc: 0.7344
# Epoch [91], last_lr: 0.01000, train_loss: 1.8691, val_loss: 0.9706, val_acc: 0.7509
# Epoch [92], last_lr: 0.01000, train_loss: 1.8744, val_loss: 0.9933, val_acc: 0.7465
# Epoch [93], last_lr: 0.01000, train_loss: 1.8441, val_loss: 0.9541, val_acc: 0.7578
# Epoch [94], last_lr: 0.01000, train_loss: 1.8986, val_loss: 0.9562, val_acc: 0.7525
# Epoch [95], last_lr: 0.01000, train_loss: 1.9422, val_loss: 1.0095, val_acc: 0.7493
# Epoch [96], last_lr: 0.01000, train_loss: 1.8784, val_loss: 0.9831, val_acc: 0.7537
# Epoch [97], last_lr: 0.01000, train_loss: 1.9522, val_loss: 1.0048, val_acc: 0.7503
# Epoch [98], last_lr: 0.01000, train_loss: 1.9207, val_loss: 0.9653, val_acc: 0.7495
# Epoch [99], last_lr: 0.01000, train_loss: 1.8433, val_loss: 1.0143, val_acc: 0.7456
# Epoch [100], last_lr: 0.01000, train_loss: 1.8650, val_loss: 1.0311, val_acc: 0.7413
# Epoch [101], last_lr: 0.01000, train_loss: 1.9117, val_loss: 1.0134, val_acc: 0.7463
# Epoch [102], last_lr: 0.01000, train_loss: 1.8319, val_loss: 0.9891, val_acc: 0.7525
# Epoch [103], last_lr: 0.01000, train_loss: 1.8983, val_loss: 1.0633, val_acc: 0.7429
# Epoch [104], last_lr: 0.01000, train_loss: 1.8777, val_loss: 1.0241, val_acc: 0.7476
# Epoch [105], last_lr: 0.01000, train_loss: 1.8945, val_loss: 0.9843, val_acc: 0.7498
# Epoch [106], last_lr: 0.01000, train_loss: 1.9180, val_loss: 1.0103, val_acc: 0.7486
# Epoch [107], last_lr: 0.01000, train_loss: 1.8843, val_loss: 0.9818, val_acc: 0.7478
# Epoch [108], last_lr: 0.01000, train_loss: 1.8888, val_loss: 0.9156, val_acc: 0.7561
# Epoch [109], last_lr: 0.01000, train_loss: 1.8963, val_loss: 1.0355, val_acc: 0.7424
# Epoch [110], last_lr: 0.01000, train_loss: 1.8068, val_loss: 0.9727, val_acc: 0.7513
# Epoch [111], last_lr: 0.01000, train_loss: 1.9063, val_loss: 1.0918, val_acc: 0.7362
# Epoch [112], last_lr: 0.00100, train_loss: 1.8426, val_loss: 0.9755, val_acc: 0.7531
# Epoch [113], last_lr: 0.00100, train_loss: 1.7872, val_loss: 1.0254, val_acc: 0.7468
# Epoch [114], last_lr: 0.00100, train_loss: 1.8409, val_loss: 0.9503, val_acc: 0.7580
# Epoch [115], last_lr: 0.00100, train_loss: 1.8150, val_loss: 1.0233, val_acc: 0.7495
# Epoch [116], last_lr: 0.00100, train_loss: 1.8122, val_loss: 0.9812, val_acc: 0.7528
# Epoch [117], last_lr: 0.00100, train_loss: 1.8684, val_loss: 1.0206, val_acc: 0.7503
# Epoch [118], last_lr: 0.00100, train_loss: 1.8327, val_loss: 0.9811, val_acc: 0.7555
# Epoch [119], last_lr: 0.00100, train_loss: 1.8015, val_loss: 0.9757, val_acc: 0.7578
# Epoch [120], last_lr: 0.00100, train_loss: 1.8285, val_loss: 0.9589, val_acc: 0.7576
# Epoch [121], last_lr: 0.00100, train_loss: 1.8492, val_loss: 0.9759, val_acc: 0.7578
# Epoch [122], last_lr: 0.00100, train_loss: 1.7742, val_loss: 0.9858, val_acc: 0.7565
# Epoch [123], last_lr: 0.00100, train_loss: 1.8202, val_loss: 0.9246, val_acc: 0.7642
# Epoch [124], last_lr: 0.00100, train_loss: 1.8273, val_loss: 0.9906, val_acc: 0.7542
# Epoch [125], last_lr: 0.00100, train_loss: 1.8023, val_loss: 0.9561, val_acc: 0.7596
# Epoch [126], last_lr: 0.00100, train_loss: 1.7836, val_loss: 0.9574, val_acc: 0.7623
# Epoch [127], last_lr: 0.00100, train_loss: 1.8362, val_loss: 0.9810, val_acc: 0.7569
# Epoch [128], last_lr: 0.00100, train_loss: 1.7610, val_loss: 0.9635, val_acc: 0.7587
# Epoch [129], last_lr: 0.00100, train_loss: 1.7915, val_loss: 1.0137, val_acc: 0.7527
# Epoch [130], last_lr: 0.00100, train_loss: 1.8267, val_loss: 0.9883, val_acc: 0.7553
# Epoch [131], last_lr: 0.00100, train_loss: 1.7796, val_loss: 0.9574, val_acc: 0.7599
# Epoch [132], last_lr: 0.00100, train_loss: 1.7911, val_loss: 0.9879, val_acc: 0.7550
# Epoch [133], last_lr: 0.00100, train_loss: 1.8403, val_loss: 0.9208, val_acc: 0.7624
# Epoch [134], last_lr: 0.00100, train_loss: 1.7406, val_loss: 0.9772, val_acc: 0.7560
# Epoch [135], last_lr: 0.00100, train_loss: 1.8217, val_loss: 0.9540, val_acc: 0.7602
# Epoch [136], last_lr: 0.00100, train_loss: 1.7471, val_loss: 0.9567, val_acc: 0.7581
# Epoch [137], last_lr: 0.00100, train_loss: 1.8364, val_loss: 0.9901, val_acc: 0.7551
# Epoch [138], last_lr: 0.00100, train_loss: 1.8017, val_loss: 0.9185, val_acc: 0.7638
# Epoch [139], last_lr: 0.00100, train_loss: 1.8271, val_loss: 0.9440, val_acc: 0.7612
# Epoch [140], last_lr: 0.00100, train_loss: 1.7688, val_loss: 0.9385, val_acc: 0.7626
# Epoch [141], last_lr: 0.00100, train_loss: 1.7546, val_loss: 0.9996, val_acc: 0.7564
# Epoch [142], last_lr: 0.00100, train_loss: 1.8198, val_loss: 0.9447, val_acc: 0.7613
# Epoch [143], last_lr: 0.00100, train_loss: 1.7594, val_loss: 0.9659, val_acc: 0.7577
# Epoch [144], last_lr: 0.00100, train_loss: 1.8359, val_loss: 0.9243, val_acc: 0.7655
# Epoch [145], last_lr: 0.00100, train_loss: 1.7988, val_loss: 0.9466, val_acc: 0.7625
# Epoch [146], last_lr: 0.00100, train_loss: 1.8331, val_loss: 0.9282, val_acc: 0.7643
# Epoch [147], last_lr: 0.00100, train_loss: 1.7341, val_loss: 0.9334, val_acc: 0.7632
# Epoch [148], last_lr: 0.00100, train_loss: 1.7947, val_loss: 0.9608, val_acc: 0.7594
# Epoch [149], last_lr: 0.00100, train_loss: 1.7520, val_loss: 0.9508, val_acc: 0.7617
# Epoch [150], last_lr: 0.00100, train_loss: 1.7492, val_loss: 0.9351, val_acc: 0.7636
# Epoch [151], last_lr: 0.00100, train_loss: 1.7652, val_loss: 1.0001, val_acc: 0.7554
# Epoch [152], last_lr: 0.00100, train_loss: 1.8074, val_loss: 0.9293, val_acc: 0.7647
# Epoch [153], last_lr: 0.00100, train_loss: 1.7747, val_loss: 0.9607, val_acc: 0.7597
# Epoch [154], last_lr: 0.00100, train_loss: 1.7456, val_loss: 0.9719, val_acc: 0.7578
# Epoch [155], last_lr: 0.00100, train_loss: 1.7962, val_loss: 0.9606, val_acc: 0.7596
# Epoch [156], last_lr: 0.00100, train_loss: 1.7877, val_loss: 0.9821, val_acc: 0.7546
# Epoch [157], last_lr: 0.00100, train_loss: 1.7589, val_loss: 0.9894, val_acc: 0.7555
# Epoch [158], last_lr: 0.00100, train_loss: 1.8100, val_loss: 0.9637, val_acc: 0.7611
# Epoch [159], last_lr: 0.00100, train_loss: 1.8236, val_loss: 1.0047, val_acc: 0.7523
# Epoch [160], last_lr: 0.00100, train_loss: 1.8280, val_loss: 0.9417, val_acc: 0.7600
# Epoch [161], last_lr: 0.00100, train_loss: 1.7586, val_loss: 0.9413, val_acc: 0.7622
# Epoch [162], last_lr: 0.00100, train_loss: 1.8331, val_loss: 0.9678, val_acc: 0.7602
# Epoch [163], last_lr: 0.00100, train_loss: 1.7701, val_loss: 0.9366, val_acc: 0.7611
# Epoch [164], last_lr: 0.00100, train_loss: 1.8161, val_loss: 0.9649, val_acc: 0.7570
# Epoch [165], last_lr: 0.00100, train_loss: 1.8208, val_loss: 0.9592, val_acc: 0.7595
# Epoch [166], last_lr: 0.00100, train_loss: 1.8478, val_loss: 0.9268, val_acc: 0.7632
# Epoch [167], last_lr: 0.00100, train_loss: 1.7692, val_loss: 0.9532, val_acc: 0.7622
# Epoch [168], last_lr: 0.00100, train_loss: 1.7943, val_loss: 0.9626, val_acc: 0.7561
# Epoch [169], last_lr: 0.00100, train_loss: 1.8233, val_loss: 0.9635, val_acc: 0.7578
# Epoch [170], last_lr: 0.00100, train_loss: 1.7951, val_loss: 0.9854, val_acc: 0.7540
# Epoch [171], last_lr: 0.00100, train_loss: 1.7928, val_loss: 0.9642, val_acc: 0.7602
# Epoch [172], last_lr: 0.00100, train_loss: 1.7652, val_loss: 0.9812, val_acc: 0.7573
# Epoch [173], last_lr: 0.00100, train_loss: 1.8241, val_loss: 0.9420, val_acc: 0.7614
# Epoch [174], last_lr: 0.00100, train_loss: 1.7964, val_loss: 0.9928, val_acc: 0.7551
# Epoch [175], last_lr: 0.00100, train_loss: 1.7180, val_loss: 0.9503, val_acc: 0.7615
# Epoch [176], last_lr: 0.00100, train_loss: 1.7701, val_loss: 1.0057, val_acc: 0.7538
# Epoch [177], last_lr: 0.00100, train_loss: 1.8001, val_loss: 0.9387, val_acc: 0.7616
# Epoch [178], last_lr: 0.00100, train_loss: 1.7392, val_loss: 0.9595, val_acc: 0.7589
# Epoch [179], last_lr: 0.00100, train_loss: 1.7652, val_loss: 1.0292, val_acc: 0.7488
# Epoch [180], last_lr: 0.00100, train_loss: 1.7491, val_loss: 0.9503, val_acc: 0.7584
# Epoch [181], last_lr: 0.00100, train_loss: 1.7736, val_loss: 0.9930, val_acc: 0.7553
# Epoch [182], last_lr: 0.00100, train_loss: 1.7716, val_loss: 0.9409, val_acc: 0.7610
# Epoch [183], last_lr: 0.00100, train_loss: 1.8268, val_loss: 0.9485, val_acc: 0.7605
# Epoch [184], last_lr: 0.00100, train_loss: 1.8124, val_loss: 1.0227, val_acc: 0.7508
# Epoch [185], last_lr: 0.00100, train_loss: 1.7383, val_loss: 0.9947, val_acc: 0.7526
# Epoch [186], last_lr: 0.00100, train_loss: 1.7699, val_loss: 0.9824, val_acc: 0.7582
# Epoch [187], last_lr: 0.00100, train_loss: 1.8143, val_loss: 1.0089, val_acc: 0.7534
# Epoch [188], last_lr: 0.00100, train_loss: 1.7422, val_loss: 0.9242, val_acc: 0.7647
# Epoch [189], last_lr: 0.00100, train_loss: 1.8117, val_loss: 0.9766, val_acc: 0.7577
# Epoch [190], last_lr: 0.00100, train_loss: 1.7644, val_loss: 0.9497, val_acc: 0.7610
# Epoch [191], last_lr: 0.00100, train_loss: 1.7254, val_loss: 0.9648, val_acc: 0.7600
# Epoch [192], last_lr: 0.00100, train_loss: 1.8357, val_loss: 0.9957, val_acc: 0.7551
# Epoch [193], last_lr: 0.00100, train_loss: 1.7433, val_loss: 0.9448, val_acc: 0.7620
# Epoch [194], last_lr: 0.00100, train_loss: 1.8153, val_loss: 0.9957, val_acc: 0.7568
# Epoch [195], last_lr: 0.00100, train_loss: 1.7390, val_loss: 0.9844, val_acc: 0.7575
# Epoch [196], last_lr: 0.00100, train_loss: 1.7772, val_loss: 0.9849, val_acc: 0.7556
# Epoch [197], last_lr: 0.00100, train_loss: 1.7474, val_loss: 0.9260, val_acc: 0.7627
# Epoch [198], last_lr: 0.00100, train_loss: 1.7940, val_loss: 0.9642, val_acc: 0.7581
# Epoch [199], last_lr: 0.00100, train_loss: 1.8179, val_loss: 1.0004, val_acc: 0.7551

# %%
def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history[:155]], "-bx")
    plt.plot([x["val_loss"] for x in history[:155]],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","test loss"])
    plt.title('MixUp Loss')
    plt.show()

def plot_testAcc(history):
    plt.plot([x.get("val_acc") for x in history[:155]], "-bx")
    plt.xlabel("Epoch")
    plt.ylabel("acc")
    plt.legend(["test Acc"])
    plt.title('MixUp Test Acc')
    plt.show()

plot_loss(history_mixup)
plot_testAcc(history_mixup)
