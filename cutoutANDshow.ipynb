# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # 使用指定GPU
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder, CIFAR100
from torchtoolbox.tools import summary
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
from collections import OrderedDict


def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)


device = get_default_device()
print('检查GPU是否可用：',device)
# !nvidia-smi
# Out:
# 检查GPU是否可用： cuda
# Sun May  8 23:22:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 94%   76C    P2   340W / 350W |  12872MiB / 24268MiB |     90%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 35%   40C    P8    33W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 从kaggle下载数据集CIFAR-100数据集

# %%
import opendatasets as od

od.download('https://www.kaggle.com/c/2021-ai-training/data')
# Out:
# Skipping, found downloaded files in "./2021-ai-training" (use force=True to force download)

# %%
data_dir = './2021-ai-training/CIFAR100'
classes = os.listdir(data_dir + "/TRAIN")
print(classes)
# Out:
# ['chair', 'rocket', 'fox', 'poppy', 'apple', 'trout', 'palm_tree', 'seal', 'bridge', 'kangaroo', 'aquarium_fish', 'dolphin', 'beetle', 'pickup_truck', 'plain', 'can', 'snake', 'squirrel', 'skunk', 'lizard', 'bicycle', 'bottle', 'caterpillar', 'flatfish', 'shrew', 'lion', 'skyscraper', 'leopard', 'mountain', 'orange', 'porcupine', 'chimpanzee', 'motorcycle', 'hamster', 'otter', 'bee', 'mouse', 'worm', 'mushroom', 'cockroach', 'crocodile', 'bowl', 'willow_tree', 'lobster', 'train', 'road', 'tank', 'rose', 'streetcar', 'camel', 'lawn_mower', 'table', 'oak_tree', 'tiger', 'bear', 'woman', 'pine_tree', 'dinosaur', 'bus', 'bed', 'butterfly', 'man', 'shark', 'sunflower', 'raccoon', 'wardrobe', 'rabbit', 'crab', 'beaver', 'lamp', 'cattle', 'orchid', 'ray', 'elephant', 'clock', 'baby', 'boy', 'castle', 'cup', 'forest', 'possum', 'sweet_pepper', 'telephone', 'maple_tree', 'tulip', 'girl', 'pear', 'television', 'whale', 'spider', 'snail', 'wolf', 'house', 'keyboard', 'couch', 'cloud', 'turtle', 'tractor', 'sea', 'plate']

# %%
# !nvidia-smi
# Out:
# Sun May  8 03:29:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 88%   60C    P8    52W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 35%   40C    P8    32W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
'''
数据预处理
'''

method='cutout'


class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """

    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            # (x,y)表示方形补丁的中心位置
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img


normalize = tt.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
train_tfms = tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
])

if method=='cutout':
    #train_tfms.append(Cutout(n_holes=1, length=16))
    tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
        Cutout(n_holes=2, length=16),
])
    
valid_tfms = tt.Compose([
#         tt.Resize(256),  # transforms.Scale(256)
#         tt.CenterCrop(224),
        tt.ToTensor(),
        normalize,
])

# 对数据做标准化
# 训练集与测试集
train_ds = ImageFolder(root=data_dir+"/TRAIN",transform=train_tfms)
valid_ds = ImageFolder(root=data_dir+"/TEST",transform=valid_tfms)

# 用pytorh读取数据
BATCH_SIZE=128
train_dl = DataLoader(train_ds,batch_size=BATCH_SIZE,shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds,batch_size=100, shuffle=False, num_workers=2)

#用CGPU读取数据集
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
    
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %%
'''
数据增强方法
'''
def mixup_data(x, y, alpha=1, device=torch.device("cuda")):
    """Returns mixed inputs, pairs of targets, and lambda"""
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size)
    index = index.to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


# def mixup_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)



def cutmix_data(x, y, alpha=1.0, device=torch.device("cuda")):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    rand_index = torch.randperm(x.size()[0]).to(device)
    y_a = y
    y_b = y[rand_index]
    bbx1, bby1, bbx2, bby2 = _rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[rand_index, :, bbx1:bbx2, bby1:bby2]
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))
    return x, y_a, y_b, lam


# def cutmix_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)


def _rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
'''
DenseNet模型
'''
class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu1', nn.ReLU(inplace=True)),
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                        growth_rate, kernel_size=1, stride=1, bias=False)),
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu2', nn.ReLU(inplace=True)),
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                        kernel_size=3, stride=1, padding=1, bias=False)),
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = super(_DenseLayer, self).forward(x)
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)


class _DenseBlock(nn.Sequential):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(num_input_features + i * growth_rate, growth_rate, bn_size, drop_rate)
            self.add_module('denselayer%d' % (i + 1), layer)


class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))


class ImageClassificationBase(nn.Module):
    def training_step(self,batch,method):
        '''
        这里更改方法
        '''
        if method=='null' or method=='cutout':
            images,labels = batch
            out = self(images)
            loss = F.cross_entropy(out,labels)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        elif method=='mixup':
            images,labels = batch
            inputs, targets_a, targets_b, lam = mixup_data(images, labels)
            out = self(inputs)
            loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
        elif method=='cutmix':
            images,labels = batch
            r = np.random.rand(1)
            cutmix_prob=0.5
            if r < cutmix_prob:
                inputs, targets_a, targets_b, lam = cutmix_data(images, labels)
                out = self(inputs)
                loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
            else:
                out = self(images)
                loss = F.cross_entropy(out,labels)
        return loss
    
    def validation_step(self,batch):
        images,labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {'val_loss': loss.detach(), 'val_acc': acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies

        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))
        
        

class DenseNet_Cifar(ImageClassificationBase):
    def __init__(self, growth_rate=12, block_config=(16, 16, 16),
                 num_init_features=24, bn_size=4, drop_rate=0, num_classes=10):

        super(DenseNet_Cifar, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=3, stride=1, padding=1, bias=False)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(num_layers=num_layers, num_input_features=num_features,
                                bn_size=bn_size, growth_rate=growth_rate, drop_rate=drop_rate)
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features, num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)
        
        # initialize conv and bn parameters
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.avg_pool2d(out, kernel_size=8, stride=1).view(features.size(0), -1)
        out = self.classifier(out)
        return out


def densenet_BC_cifar(depth, k, **kwargs):
    N = (depth - 4) // 6
    model = DenseNet_Cifar(growth_rate=k, block_config=[N, N, N], num_init_features=2*k, **kwargs)
    return model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

def adjust_learning_rate(optimizer, epoch):
    if epoch < 75:
        lrr = lr
    elif epoch < 112:
        lrr = lr * 0.1
    else:
        lrr = lr * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lrr

# %%
'''
训练
'''
import math
#调节depth可以调节层数
model = densenet_BC_cifar(depth=100, k=12, num_classes=100)
model = to_device(model,device)

epochs=150
lr=0.1
momentum=0.9
weight_decay=1e-4
optimizer = torch.optim.SGD(model.parameters(), lr, momentum=momentum, weight_decay=weight_decay)

def Train (epochs,train_dl,valid_dl,model,optimizer,method):
    torch.cuda.empty_cache()
    
    history = []
        
    for epoch in range(epochs):
        adjust_learning_rate(optimizer, epoch)
        model.train()
        train_loss = []
        lrs = []
        
        for batch in train_dl:
            loss = model.training_step(batch,method)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            train_loss.append(loss)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lrs.append(get_lr(optimizer))

    
        result = evaluate(model,valid_dl)
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["lrs"] = lrs
        
        model.epoch_end(epoch,result)
        history.append(result)
        
    return history
            

@torch.no_grad()
def evaluate(model,valid_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in valid_dl]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
history_cutout = []
history_cutout += Train(epochs=epochs,train_dl=train_dl,valid_dl=valid_dl,model=model,optimizer=optimizer,method=method)
# Out:
# Epoch [0], last_lr: 0.10000, train_loss: 3.9238, val_loss: 3.6706, val_acc: 0.1341
# Epoch [1], last_lr: 0.10000, train_loss: 3.2822, val_loss: 3.5668, val_acc: 0.1861
# Epoch [2], last_lr: 0.10000, train_loss: 2.7357, val_loss: 2.6905, val_acc: 0.3131
# Epoch [3], last_lr: 0.10000, train_loss: 2.3649, val_loss: 2.3289, val_acc: 0.3915
# Epoch [4], last_lr: 0.10000, train_loss: 2.0854, val_loss: 2.2946, val_acc: 0.4078
# Epoch [5], last_lr: 0.10000, train_loss: 1.8882, val_loss: 2.0690, val_acc: 0.4509
# Epoch [6], last_lr: 0.10000, train_loss: 1.7388, val_loss: 1.8607, val_acc: 0.4906
# Epoch [7], last_lr: 0.10000, train_loss: 1.6225, val_loss: 1.8638, val_acc: 0.5047
# Epoch [8], last_lr: 0.10000, train_loss: 1.5136, val_loss: 2.0825, val_acc: 0.4764
# Epoch [9], last_lr: 0.10000, train_loss: 1.4255, val_loss: 1.7866, val_acc: 0.5261
# Epoch [10], last_lr: 0.10000, train_loss: 1.3628, val_loss: 1.7849, val_acc: 0.5267
# Epoch [11], last_lr: 0.10000, train_loss: 1.2842, val_loss: 1.7925, val_acc: 0.5344
# Epoch [12], last_lr: 0.10000, train_loss: 1.2268, val_loss: 1.7566, val_acc: 0.5325
# Epoch [13], last_lr: 0.10000, train_loss: 1.1896, val_loss: 1.5950, val_acc: 0.5709
# Epoch [14], last_lr: 0.10000, train_loss: 1.1404, val_loss: 1.7271, val_acc: 0.5632
# Epoch [15], last_lr: 0.10000, train_loss: 1.1085, val_loss: 1.7216, val_acc: 0.5625
# Epoch [16], last_lr: 0.10000, train_loss: 1.0647, val_loss: 1.6249, val_acc: 0.5739
# Epoch [17], last_lr: 0.10000, train_loss: 1.0340, val_loss: 1.6096, val_acc: 0.5809
# Epoch [18], last_lr: 0.10000, train_loss: 1.0113, val_loss: 1.5292, val_acc: 0.5915
# Epoch [19], last_lr: 0.10000, train_loss: 0.9752, val_loss: 1.6008, val_acc: 0.5829
# Epoch [20], last_lr: 0.10000, train_loss: 0.9501, val_loss: 1.4167, val_acc: 0.6197
# Epoch [21], last_lr: 0.10000, train_loss: 0.9214, val_loss: 1.5437, val_acc: 0.5998
# Epoch [22], last_lr: 0.10000, train_loss: 0.9147, val_loss: 1.5257, val_acc: 0.6056
# Epoch [23], last_lr: 0.10000, train_loss: 0.8946, val_loss: 1.6393, val_acc: 0.5881
# Epoch [24], last_lr: 0.10000, train_loss: 0.8740, val_loss: 1.5186, val_acc: 0.6108
# Epoch [25], last_lr: 0.10000, train_loss: 0.8538, val_loss: 1.6172, val_acc: 0.5950
# Epoch [26], last_lr: 0.10000, train_loss: 0.8393, val_loss: 1.4917, val_acc: 0.6100
# Epoch [27], last_lr: 0.10000, train_loss: 0.8208, val_loss: 1.5238, val_acc: 0.6111
# Epoch [28], last_lr: 0.10000, train_loss: 0.8042, val_loss: 1.6119, val_acc: 0.6056
# Epoch [29], last_lr: 0.10000, train_loss: 0.7970, val_loss: 1.6410, val_acc: 0.5952
# Epoch [30], last_lr: 0.10000, train_loss: 0.7816, val_loss: 1.6172, val_acc: 0.6006
# Epoch [31], last_lr: 0.10000, train_loss: 0.7716, val_loss: 1.4997, val_acc: 0.6194
# Epoch [32], last_lr: 0.10000, train_loss: 0.7549, val_loss: 1.5179, val_acc: 0.6286
# Epoch [33], last_lr: 0.10000, train_loss: 0.7462, val_loss: 1.6877, val_acc: 0.5972
# Epoch [34], last_lr: 0.10000, train_loss: 0.7361, val_loss: 1.7104, val_acc: 0.6068
# Epoch [35], last_lr: 0.10000, train_loss: 0.7219, val_loss: 1.4707, val_acc: 0.6210
# Epoch [36], last_lr: 0.10000, train_loss: 0.7145, val_loss: 1.5563, val_acc: 0.6243
# Epoch [37], last_lr: 0.10000, train_loss: 0.7116, val_loss: 1.5941, val_acc: 0.6101
# Epoch [38], last_lr: 0.10000, train_loss: 0.6910, val_loss: 1.5106, val_acc: 0.6315
# Epoch [39], last_lr: 0.10000, train_loss: 0.6897, val_loss: 1.6384, val_acc: 0.6114
# Epoch [40], last_lr: 0.10000, train_loss: 0.6719, val_loss: 1.8346, val_acc: 0.5871
# Epoch [41], last_lr: 0.10000, train_loss: 0.6712, val_loss: 1.6918, val_acc: 0.6096
# Epoch [42], last_lr: 0.10000, train_loss: 0.6664, val_loss: 1.5742, val_acc: 0.6181
# Epoch [43], last_lr: 0.10000, train_loss: 0.6648, val_loss: 1.5171, val_acc: 0.6307
# Epoch [44], last_lr: 0.10000, train_loss: 0.6478, val_loss: 1.5528, val_acc: 0.6254
# Epoch [45], last_lr: 0.10000, train_loss: 0.6379, val_loss: 1.4295, val_acc: 0.6365
# Epoch [46], last_lr: 0.10000, train_loss: 0.6385, val_loss: 1.7445, val_acc: 0.5993
# Epoch [47], last_lr: 0.10000, train_loss: 0.6347, val_loss: 1.6117, val_acc: 0.6181
# Epoch [48], last_lr: 0.10000, train_loss: 0.6121, val_loss: 1.5511, val_acc: 0.6296
# Epoch [49], last_lr: 0.10000, train_loss: 0.6181, val_loss: 1.4600, val_acc: 0.6521
# Epoch [50], last_lr: 0.10000, train_loss: 0.6128, val_loss: 1.5119, val_acc: 0.6309
# Epoch [51], last_lr: 0.10000, train_loss: 0.6019, val_loss: 1.5589, val_acc: 0.6327
# Epoch [52], last_lr: 0.10000, train_loss: 0.5962, val_loss: 1.5271, val_acc: 0.6397
# Epoch [53], last_lr: 0.10000, train_loss: 0.5949, val_loss: 1.4090, val_acc: 0.6497
# Epoch [54], last_lr: 0.10000, train_loss: 0.5886, val_loss: 1.8410, val_acc: 0.5834
# Epoch [55], last_lr: 0.10000, train_loss: 0.5773, val_loss: 1.5885, val_acc: 0.6232
# Epoch [56], last_lr: 0.10000, train_loss: 0.5733, val_loss: 1.4592, val_acc: 0.6521
# Epoch [57], last_lr: 0.10000, train_loss: 0.5570, val_loss: 1.4257, val_acc: 0.6491
# Epoch [58], last_lr: 0.10000, train_loss: 0.5754, val_loss: 1.5342, val_acc: 0.6342
# Epoch [59], last_lr: 0.10000, train_loss: 0.5654, val_loss: 1.6931, val_acc: 0.6083
# Epoch [60], last_lr: 0.10000, train_loss: 0.5621, val_loss: 1.6110, val_acc: 0.6256
# Epoch [61], last_lr: 0.10000, train_loss: 0.5524, val_loss: 1.5408, val_acc: 0.6443
# Epoch [62], last_lr: 0.10000, train_loss: 0.5518, val_loss: 1.4756, val_acc: 0.6512
# Epoch [63], last_lr: 0.10000, train_loss: 0.5382, val_loss: 1.7402, val_acc: 0.6125
# Epoch [64], last_lr: 0.10000, train_loss: 0.5495, val_loss: 1.4563, val_acc: 0.6366
# Epoch [65], last_lr: 0.10000, train_loss: 0.5305, val_loss: 1.4749, val_acc: 0.6440
# Epoch [66], last_lr: 0.10000, train_loss: 0.5293, val_loss: 1.3935, val_acc: 0.6634
# Epoch [67], last_lr: 0.10000, train_loss: 0.5299, val_loss: 1.5909, val_acc: 0.6339
# Epoch [68], last_lr: 0.10000, train_loss: 0.5346, val_loss: 1.6538, val_acc: 0.6239
# Epoch [69], last_lr: 0.10000, train_loss: 0.5311, val_loss: 1.4510, val_acc: 0.6448
# Epoch [70], last_lr: 0.10000, train_loss: 0.5165, val_loss: 1.5319, val_acc: 0.6387
# Epoch [71], last_lr: 0.10000, train_loss: 0.5149, val_loss: 1.5841, val_acc: 0.6350
# Epoch [72], last_lr: 0.10000, train_loss: 0.5172, val_loss: 1.4275, val_acc: 0.6538
# Epoch [73], last_lr: 0.10000, train_loss: 0.5016, val_loss: 1.6383, val_acc: 0.6328
# Epoch [74], last_lr: 0.10000, train_loss: 0.5075, val_loss: 1.7249, val_acc: 0.6119
# Epoch [75], last_lr: 0.01000, train_loss: 0.2583, val_loss: 1.0287, val_acc: 0.7362
# Epoch [76], last_lr: 0.01000, train_loss: 0.1721, val_loss: 1.0308, val_acc: 0.7392
# Epoch [77], last_lr: 0.01000, train_loss: 0.1465, val_loss: 1.0458, val_acc: 0.7409
# Epoch [78], last_lr: 0.01000, train_loss: 0.1281, val_loss: 1.0454, val_acc: 0.7437
# Epoch [79], last_lr: 0.01000, train_loss: 0.1140, val_loss: 1.0504, val_acc: 0.7432
# Epoch [80], last_lr: 0.01000, train_loss: 0.1066, val_loss: 1.0618, val_acc: 0.7430
# Epoch [81], last_lr: 0.01000, train_loss: 0.0973, val_loss: 1.0742, val_acc: 0.7454
# Epoch [82], last_lr: 0.01000, train_loss: 0.0900, val_loss: 1.0812, val_acc: 0.7424
# Epoch [83], last_lr: 0.01000, train_loss: 0.0845, val_loss: 1.0894, val_acc: 0.7446
# Epoch [84], last_lr: 0.01000, train_loss: 0.0785, val_loss: 1.1028, val_acc: 0.7444
# Epoch [85], last_lr: 0.01000, train_loss: 0.0746, val_loss: 1.1150, val_acc: 0.7412
# Epoch [86], last_lr: 0.01000, train_loss: 0.0723, val_loss: 1.1218, val_acc: 0.7421
# Epoch [87], last_lr: 0.01000, train_loss: 0.0685, val_loss: 1.1247, val_acc: 0.7432
# Epoch [88], last_lr: 0.01000, train_loss: 0.0637, val_loss: 1.1338, val_acc: 0.7439
# Epoch [89], last_lr: 0.01000, train_loss: 0.0614, val_loss: 1.1432, val_acc: 0.7430
# Epoch [90], last_lr: 0.01000, train_loss: 0.0562, val_loss: 1.1385, val_acc: 0.7444
# Epoch [91], last_lr: 0.01000, train_loss: 0.0565, val_loss: 1.1553, val_acc: 0.7424
# Epoch [92], last_lr: 0.01000, train_loss: 0.0544, val_loss: 1.1504, val_acc: 0.7432
# Epoch [93], last_lr: 0.01000, train_loss: 0.0516, val_loss: 1.1565, val_acc: 0.7449
# Epoch [94], last_lr: 0.01000, train_loss: 0.0504, val_loss: 1.1607, val_acc: 0.7407
# Epoch [95], last_lr: 0.01000, train_loss: 0.0487, val_loss: 1.1687, val_acc: 0.7395
# Epoch [96], last_lr: 0.01000, train_loss: 0.0477, val_loss: 1.1780, val_acc: 0.7438
# Epoch [97], last_lr: 0.01000, train_loss: 0.0444, val_loss: 1.1724, val_acc: 0.7422
# Epoch [98], last_lr: 0.01000, train_loss: 0.0446, val_loss: 1.1858, val_acc: 0.7409
# Epoch [99], last_lr: 0.01000, train_loss: 0.0426, val_loss: 1.1866, val_acc: 0.7431
# Epoch [100], last_lr: 0.01000, train_loss: 0.0403, val_loss: 1.1944, val_acc: 0.7420
# Epoch [101], last_lr: 0.01000, train_loss: 0.0392, val_loss: 1.2003, val_acc: 0.7411
# Epoch [102], last_lr: 0.01000, train_loss: 0.0385, val_loss: 1.1961, val_acc: 0.7421
# Epoch [103], last_lr: 0.01000, train_loss: 0.0377, val_loss: 1.2065, val_acc: 0.7406
# Epoch [104], last_lr: 0.01000, train_loss: 0.0365, val_loss: 1.2026, val_acc: 0.7420
# Epoch [105], last_lr: 0.01000, train_loss: 0.0352, val_loss: 1.2136, val_acc: 0.7425
# Epoch [106], last_lr: 0.01000, train_loss: 0.0358, val_loss: 1.2167, val_acc: 0.7412
# Epoch [107], last_lr: 0.01000, train_loss: 0.0354, val_loss: 1.2196, val_acc: 0.7428
# Epoch [108], last_lr: 0.01000, train_loss: 0.0342, val_loss: 1.2186, val_acc: 0.7435
# Epoch [109], last_lr: 0.01000, train_loss: 0.0323, val_loss: 1.2199, val_acc: 0.7444
# Epoch [110], last_lr: 0.01000, train_loss: 0.0321, val_loss: 1.2216, val_acc: 0.7424
# Epoch [111], last_lr: 0.01000, train_loss: 0.0309, val_loss: 1.2270, val_acc: 0.7437
# Epoch [112], last_lr: 0.00100, train_loss: 0.0281, val_loss: 1.2267, val_acc: 0.7443
# Epoch [113], last_lr: 0.00100, train_loss: 0.0278, val_loss: 1.2291, val_acc: 0.7452
# Epoch [114], last_lr: 0.00100, train_loss: 0.0276, val_loss: 1.2181, val_acc: 0.7450
# Epoch [115], last_lr: 0.00100, train_loss: 0.0268, val_loss: 1.2247, val_acc: 0.7436
# Epoch [116], last_lr: 0.00100, train_loss: 0.0264, val_loss: 1.2170, val_acc: 0.7441
# Epoch [117], last_lr: 0.00100, train_loss: 0.0264, val_loss: 1.2223, val_acc: 0.7438
# Epoch [118], last_lr: 0.00100, train_loss: 0.0251, val_loss: 1.2213, val_acc: 0.7434
# Epoch [119], last_lr: 0.00100, train_loss: 0.0260, val_loss: 1.2249, val_acc: 0.7451
# Epoch [120], last_lr: 0.00100, train_loss: 0.0264, val_loss: 1.2191, val_acc: 0.7441
# Epoch [121], last_lr: 0.00100, train_loss: 0.0255, val_loss: 1.2181, val_acc: 0.7444
# Epoch [122], last_lr: 0.00100, train_loss: 0.0260, val_loss: 1.2260, val_acc: 0.7441
# Epoch [123], last_lr: 0.00100, train_loss: 0.0250, val_loss: 1.2247, val_acc: 0.7429
# Epoch [124], last_lr: 0.00100, train_loss: 0.0250, val_loss: 1.2175, val_acc: 0.7452
# Epoch [125], last_lr: 0.00100, train_loss: 0.0255, val_loss: 1.2186, val_acc: 0.7441
# Epoch [126], last_lr: 0.00100, train_loss: 0.0251, val_loss: 1.2281, val_acc: 0.7449
# Epoch [127], last_lr: 0.00100, train_loss: 0.0256, val_loss: 1.2253, val_acc: 0.7447
# Epoch [128], last_lr: 0.00100, train_loss: 0.0245, val_loss: 1.2197, val_acc: 0.7456
# Epoch [129], last_lr: 0.00100, train_loss: 0.0249, val_loss: 1.2284, val_acc: 0.7420
# Epoch [130], last_lr: 0.00100, train_loss: 0.0247, val_loss: 1.2225, val_acc: 0.7439
# Epoch [131], last_lr: 0.00100, train_loss: 0.0249, val_loss: 1.2205, val_acc: 0.7432
# Epoch [132], last_lr: 0.00100, train_loss: 0.0240, val_loss: 1.2296, val_acc: 0.7434
# Epoch [133], last_lr: 0.00100, train_loss: 0.0244, val_loss: 1.2174, val_acc: 0.7453
# Epoch [134], last_lr: 0.00100, train_loss: 0.0249, val_loss: 1.2275, val_acc: 0.7452
# Epoch [135], last_lr: 0.00100, train_loss: 0.0233, val_loss: 1.2229, val_acc: 0.7458
# Epoch [136], last_lr: 0.00100, train_loss: 0.0243, val_loss: 1.2225, val_acc: 0.7455
# Epoch [137], last_lr: 0.00100, train_loss: 0.0235, val_loss: 1.2218, val_acc: 0.7446
# Epoch [138], last_lr: 0.00100, train_loss: 0.0237, val_loss: 1.2240, val_acc: 0.7442
# Epoch [139], last_lr: 0.00100, train_loss: 0.0236, val_loss: 1.2266, val_acc: 0.7457
# Epoch [140], last_lr: 0.00100, train_loss: 0.0238, val_loss: 1.2245, val_acc: 0.7439
# Epoch [141], last_lr: 0.00100, train_loss: 0.0242, val_loss: 1.2276, val_acc: 0.7442
# Epoch [142], last_lr: 0.00100, train_loss: 0.0243, val_loss: 1.2269, val_acc: 0.7450
# Epoch [143], last_lr: 0.00100, train_loss: 0.0241, val_loss: 1.2297, val_acc: 0.7443
# Epoch [144], last_lr: 0.00100, train_loss: 0.0233, val_loss: 1.2283, val_acc: 0.7443
# Epoch [145], last_lr: 0.00100, train_loss: 0.0235, val_loss: 1.2256, val_acc: 0.7436
# Epoch [146], last_lr: 0.00100, train_loss: 0.0237, val_loss: 1.2295, val_acc: 0.7452
# Epoch [147], last_lr: 0.00100, train_loss: 0.0234, val_loss: 1.2288, val_acc: 0.7445
# Epoch [148], last_lr: 0.00100, train_loss: 0.0233, val_loss: 1.2267, val_acc: 0.7446
# Epoch [149], last_lr: 0.00100, train_loss: 0.0232, val_loss: 1.2244, val_acc: 0.7460

# %% [markdown]
# # CutOut

# %%
# #%%time
# history_cutout = []
# history_cutout += Train(epochs=epochs,train_dl=train_dl,valid_dl=valid_dl,model=model,optimizer=optimizer,method=method)

def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history], "-bx")
    plt.plot([x["val_loss"] for x in history],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","test loss"])
    plt.title('CutOut Loss')
    plt.show()

def plot_testAcc(history):
    plt.plot([x.get("val_acc") for x in history], "-bx")
    plt.xlabel("Epoch")
    plt.ylabel("acc")
    plt.legend(["test Acc"])
    plt.title('CutOut Test Acc')
    plt.show()

plot_loss(history_cutout)
plot_testAcc(history_cutout)

torch.save(model.state_dict(),'model_cutout.pt')

# %%
'''
数据预处理
'''
import warnings
warnings.filterwarnings("ignore")

method='null'
normalize = tt.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
train_tfms = tt.Compose([
#         tt.RandomCrop(32, padding=4),
#         tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        #normalize,
])

if method=='cutout':
    #train_tfms.append(Cutout(n_holes=1, length=16))
    tt.Compose([
#         tt.RandomCrop(32, padding=4),
#         tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        #normalize,
        Cutout(n_holes=1, length=8),
])
    
valid_tfms = tt.Compose([
        tt.ToTensor(),
        normalize,
])

# 对数据做标准化
# 训练集与测试集
train_ds = ImageFolder(root=data_dir+"/TRAIN",transform=train_tfms)
valid_ds = ImageFolder(root=data_dir+"/TEST",transform=valid_tfms)

# 用pytorh读取数据
BATCH_SIZE=32
train_dl = DataLoader(train_ds,batch_size=BATCH_SIZE,shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds,batch_size=100, shuffle=False, num_workers=2)

#用CGPU读取数据集
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
    
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device) 


print("未经过处理的三张图片：")
imgs, labels = next(iter(train_dl))
imgs=imgs[0:3].to('cpu')
temp=make_grid(imgs).numpy().transpose(1, 2, 0)
plt.imshow(temp)
plt.show()

print("经过CutOut处理,剪出2个length为8的矩形的三张图片：")
cut=Cutout(n_holes=2,length=8)
imgs_cutout=[]
for i in range(3):
    imgs_cutout.append(cut(imgs[i]))
temp=make_grid(imgs_cutout).numpy().transpose(1, 2, 0)
plt.imshow(temp)
plt.show()

print("经过mixup处理的三张图片：")
imgs_mixup , t_a, t_b, lam =mixup_data(imgs,labels, alpha=1)
temp = make_grid(imgs_mixup).numpy().transpose(1, 2, 0)
plt.imshow(temp)
plt.show()

print("经过cutmix处理的三张图片：")
imgs_cutmix, y_a, y_b, lam = cutmix_data(imgs, labels)
temp = make_grid(imgs_cutmix).numpy().transpose(1, 2, 0)
plt.imshow(temp)
plt.show()
# Out:
# 未经过处理的三张图片：
# 经过CutOut处理,剪出2个length为8的矩形的三张图片：
# 经过mixup处理的三张图片：
# 经过cutmix处理的三张图片：
