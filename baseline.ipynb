# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # 使用指定GPU
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder, CIFAR100
from torchtoolbox.tools import summary
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
from collections import OrderedDict


def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)


device = get_default_device()
print('检查GPU是否可用：',device)
# !nvidia-smi
# Out:
# 检查GPU是否可用： cuda
# Sun May  8 15:47:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 32%   38C    P8    39W / 350W |   6437MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 81%   55C    P8    38W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 从kaggle下载数据集CIFAR-100数据集

# %%
import opendatasets as od

od.download('https://www.kaggle.com/c/2021-ai-training/data')
# Out:
# Skipping, found downloaded files in "./2021-ai-training" (use force=True to force download)

# %%
data_dir = './2021-ai-training/CIFAR100'
classes = os.listdir(data_dir + "/TRAIN")
print(classes)
# Out:
# ['chair', 'rocket', 'fox', 'poppy', 'apple', 'trout', 'palm_tree', 'seal', 'bridge', 'kangaroo', 'aquarium_fish', 'dolphin', 'beetle', 'pickup_truck', 'plain', 'can', 'snake', 'squirrel', 'skunk', 'lizard', 'bicycle', 'bottle', 'caterpillar', 'flatfish', 'shrew', 'lion', 'skyscraper', 'leopard', 'mountain', 'orange', 'porcupine', 'chimpanzee', 'motorcycle', 'hamster', 'otter', 'bee', 'mouse', 'worm', 'mushroom', 'cockroach', 'crocodile', 'bowl', 'willow_tree', 'lobster', 'train', 'road', 'tank', 'rose', 'streetcar', 'camel', 'lawn_mower', 'table', 'oak_tree', 'tiger', 'bear', 'woman', 'pine_tree', 'dinosaur', 'bus', 'bed', 'butterfly', 'man', 'shark', 'sunflower', 'raccoon', 'wardrobe', 'rabbit', 'crab', 'beaver', 'lamp', 'cattle', 'orchid', 'ray', 'elephant', 'clock', 'baby', 'boy', 'castle', 'cup', 'forest', 'possum', 'sweet_pepper', 'telephone', 'maple_tree', 'tulip', 'girl', 'pear', 'television', 'whale', 'spider', 'snail', 'wolf', 'house', 'keyboard', 'couch', 'cloud', 'turtle', 'tractor', 'sea', 'plate']

# %%
# !nvidia-smi
# Out:
# Sun May  8 15:47:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.56       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:0C:00.0 Off |                  N/A |
# | 32%   38C    P8    39W / 350W |   6437MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:0D:00.0 Off |                  N/A |
# | 76%   52C    P8    36W / 350W |   9170MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
'''
数据预处理
'''

method='null'


class Cutout(object):
    """Randomly mask out one or more patches from an image.
    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """

    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            # (x,y)表示方形补丁的中心位置
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img


normalize = tt.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
train_tfms = tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
])

if method=='cutout':
    #train_tfms.append(Cutout(n_holes=1, length=16))
    tt.Compose([
        tt.RandomCrop(32, padding=4),
        tt.RandomHorizontalFlip(),
        tt.ToTensor(),
        normalize,
        Cutout(n_holes=1, length=8),
])
    
valid_tfms = tt.Compose([
#         tt.Resize(256),  # transforms.Scale(256)
#         tt.CenterCrop(224),
        tt.ToTensor(),
        normalize,
])

# 对数据做标准化
# 训练集与测试集
train_ds = ImageFolder(root=data_dir+"/TRAIN",transform=train_tfms)
valid_ds = ImageFolder(root=data_dir+"/TEST",transform=valid_tfms)

# 用pytorh读取数据
BATCH_SIZE=128
train_dl = DataLoader(train_ds,batch_size=BATCH_SIZE,shuffle=True, num_workers=2)
valid_dl = DataLoader(valid_ds,batch_size=100, shuffle=False, num_workers=2)

#用CGPU读取数据集
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
    
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %%
'''
数据增强方法
'''
def mixup_data(x, y, alpha=1, device=torch.device("cuda")):
    """Returns mixed inputs, pairs of targets, and lambda"""
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size)
    index = index.to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


# def mixup_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)



def cutmix_data(x, y, alpha=1.0, device=torch.device("cuda")):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1
    rand_index = torch.randperm(x.size()[0]).to(device)
    y_a = y
    y_b = y[rand_index]
    bbx1, bby1, bbx2, bby2 = _rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[rand_index, :, bbx1:bbx2, bby1:bby2]
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))
    return x, y_a, y_b, lam


# def cutmix_criterion(criterion, pred, y_a, y_b, lam):
#     return lam * criterion(pred, y_a) + (1. - lam) * criterion(pred, y_b)


def _rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
'''
DenseNet模型
'''
class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu1', nn.ReLU(inplace=True)),
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                        growth_rate, kernel_size=1, stride=1, bias=False)),
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu2', nn.ReLU(inplace=True)),
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                        kernel_size=3, stride=1, padding=1, bias=False)),
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = super(_DenseLayer, self).forward(x)
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)


class _DenseBlock(nn.Sequential):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(num_input_features + i * growth_rate, growth_rate, bn_size, drop_rate)
            self.add_module('denselayer%d' % (i + 1), layer)


class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))


class ImageClassificationBase(nn.Module):
    def training_step(self,batch,method):
        '''
        这里更改方法
        '''
        if method=='null' or method=='cutout':
            images,labels = batch
            out = self(images)
            loss = F.cross_entropy(out,labels)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        elif method=='mixup':
            images,labels = batch
            inputs, targets_a, targets_b, lam = mixup_data(images, labels)
            out = self(inputs)
            loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
        elif method=='cutmix':
            images,labels = batch
            r = np.random.rand(1)
            cutmix_prob=0.5
            if r < cutmix_prob:
                inputs, targets_a, targets_b, lam = cutmix_data(images, labels)
                out = self(inputs)
                loss = lam * F.cross_entropy(out, targets_a) + (1. - lam) * F.cross_entropy(out, targets_b)
            else:
                out = self(images)
                loss = F.cross_entropy(out,labels)
        return loss
    
    def validation_step(self,batch):
        images,labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {'val_loss': loss.detach(), 'val_acc': acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies

        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))
        
        

class DenseNet_Cifar(ImageClassificationBase):
    def __init__(self, growth_rate=12, block_config=(16, 16, 16),
                 num_init_features=24, bn_size=4, drop_rate=0, num_classes=10):

        super(DenseNet_Cifar, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=3, stride=1, padding=1, bias=False)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(num_layers=num_layers, num_input_features=num_features,
                                bn_size=bn_size, growth_rate=growth_rate, drop_rate=drop_rate)
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features, num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)
        
        # initialize conv and bn parameters
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.avg_pool2d(out, kernel_size=8, stride=1).view(features.size(0), -1)
        out = self.classifier(out)
        return out


def densenet_BC_cifar(depth, k, **kwargs):
    N = (depth - 4) // 6
    model = DenseNet_Cifar(growth_rate=k, block_config=[N, N, N], num_init_features=2*k, **kwargs)
    return model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

def adjust_learning_rate(optimizer, epoch):
    if epoch < 75:
        lrr = lr
    elif epoch < 112:
        lrr = lr * 0.1
    else:
        lrr = lr * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lrr

# %%
'''
训练
'''
import math
#调节depth可以调节层数
model = densenet_BC_cifar(depth=100, k=12, num_classes=100)
model = to_device(model,device)

epochs=150
lr=0.1
momentum=0.9
weight_decay=1e-4
optimizer = torch.optim.SGD(model.parameters(), lr, momentum=momentum, weight_decay=weight_decay)

def Train (epochs,train_dl,valid_dl,model,optimizer,method):
    torch.cuda.empty_cache()
    
    history = []
        
    for epoch in range(epochs):
        adjust_learning_rate(optimizer, epoch)
        model.train()
        train_loss = []
        lrs = []
        
        for batch in train_dl:
            loss = model.training_step(batch,method)#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            train_loss.append(loss)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lrs.append(get_lr(optimizer))

    
        result = evaluate(model,valid_dl)
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["lrs"] = lrs
        
        model.epoch_end(epoch,result)
        history.append(result)
        
    return history
            

@torch.no_grad()
def evaluate(model,valid_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in valid_dl]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %% [markdown]
# # BaseLine

# %%
print('无处理训练过程：')
history_none = []
history_none += Train(epochs=epochs,train_dl=train_dl,valid_dl=valid_dl,model=model,optimizer=optimizer,method='null')


torch.save(model.state_dict(),'model_none.pt')
# Out:
# 无处理训练过程：
# Epoch [0], last_lr: 0.10000, train_loss: 3.8907, val_loss: 3.6054, val_acc: 0.1491
# Epoch [1], last_lr: 0.10000, train_loss: 3.2308, val_loss: 3.2077, val_acc: 0.2249
# Epoch [2], last_lr: 0.10000, train_loss: 2.7175, val_loss: 2.7403, val_acc: 0.3158
# Epoch [3], last_lr: 0.10000, train_loss: 2.3455, val_loss: 2.5456, val_acc: 0.3536
# Epoch [4], last_lr: 0.10000, train_loss: 2.0793, val_loss: 2.2130, val_acc: 0.4245
# Epoch [5], last_lr: 0.10000, train_loss: 1.8814, val_loss: 2.0696, val_acc: 0.4547
# Epoch [6], last_lr: 0.10000, train_loss: 1.7439, val_loss: 1.9472, val_acc: 0.4770
# Epoch [7], last_lr: 0.10000, train_loss: 1.6101, val_loss: 1.8507, val_acc: 0.5149
# Epoch [8], last_lr: 0.10000, train_loss: 1.5063, val_loss: 1.7799, val_acc: 0.5221
# Epoch [9], last_lr: 0.10000, train_loss: 1.4225, val_loss: 1.8691, val_acc: 0.5160
# Epoch [10], last_lr: 0.10000, train_loss: 1.3589, val_loss: 1.6982, val_acc: 0.5461
# Epoch [11], last_lr: 0.10000, train_loss: 1.2972, val_loss: 1.7428, val_acc: 0.5495
# Epoch [12], last_lr: 0.10000, train_loss: 1.2427, val_loss: 1.7096, val_acc: 0.5463
# Epoch [13], last_lr: 0.10000, train_loss: 1.1943, val_loss: 1.6793, val_acc: 0.5610
# Epoch [14], last_lr: 0.10000, train_loss: 1.1493, val_loss: 1.5418, val_acc: 0.5865
# Epoch [15], last_lr: 0.10000, train_loss: 1.1084, val_loss: 1.5565, val_acc: 0.5797
# Epoch [16], last_lr: 0.10000, train_loss: 1.0771, val_loss: 1.6154, val_acc: 0.5793
# Epoch [17], last_lr: 0.10000, train_loss: 1.0494, val_loss: 1.5219, val_acc: 0.5901
# Epoch [18], last_lr: 0.10000, train_loss: 1.0189, val_loss: 1.5236, val_acc: 0.5947
# Epoch [19], last_lr: 0.10000, train_loss: 0.9989, val_loss: 1.4768, val_acc: 0.6132
# Epoch [20], last_lr: 0.10000, train_loss: 0.9758, val_loss: 1.4634, val_acc: 0.6159
# Epoch [21], last_lr: 0.10000, train_loss: 0.9525, val_loss: 1.6133, val_acc: 0.5891
# Epoch [22], last_lr: 0.10000, train_loss: 0.9167, val_loss: 1.4519, val_acc: 0.6178
# Epoch [23], last_lr: 0.10000, train_loss: 0.9084, val_loss: 1.6525, val_acc: 0.5990
# Epoch [24], last_lr: 0.10000, train_loss: 0.8816, val_loss: 1.4765, val_acc: 0.6172
# Epoch [25], last_lr: 0.10000, train_loss: 0.8702, val_loss: 1.4034, val_acc: 0.6271
# Epoch [26], last_lr: 0.10000, train_loss: 0.8509, val_loss: 1.4686, val_acc: 0.6182
# Epoch [27], last_lr: 0.10000, train_loss: 0.8338, val_loss: 1.5099, val_acc: 0.6084
# Epoch [28], last_lr: 0.10000, train_loss: 0.8302, val_loss: 1.6875, val_acc: 0.5877
# Epoch [29], last_lr: 0.10000, train_loss: 0.8174, val_loss: 1.5746, val_acc: 0.6023
# Epoch [30], last_lr: 0.10000, train_loss: 0.7971, val_loss: 1.4639, val_acc: 0.6238
# Epoch [31], last_lr: 0.10000, train_loss: 0.7854, val_loss: 1.5176, val_acc: 0.6197
# Epoch [32], last_lr: 0.10000, train_loss: 0.7789, val_loss: 1.4308, val_acc: 0.6297
# Epoch [33], last_lr: 0.10000, train_loss: 0.7540, val_loss: 1.5322, val_acc: 0.6209
# Epoch [34], last_lr: 0.10000, train_loss: 0.7493, val_loss: 1.4576, val_acc: 0.6256
# Epoch [35], last_lr: 0.10000, train_loss: 0.7374, val_loss: 1.5052, val_acc: 0.6325
# Epoch [36], last_lr: 0.10000, train_loss: 0.7297, val_loss: 1.5961, val_acc: 0.6082
# Epoch [37], last_lr: 0.10000, train_loss: 0.7279, val_loss: 1.4675, val_acc: 0.6337
# Epoch [38], last_lr: 0.10000, train_loss: 0.7205, val_loss: 1.6515, val_acc: 0.6009
# Epoch [39], last_lr: 0.10000, train_loss: 0.7081, val_loss: 1.6124, val_acc: 0.6208
# Epoch [40], last_lr: 0.10000, train_loss: 0.7030, val_loss: 1.6672, val_acc: 0.6083
# Epoch [41], last_lr: 0.10000, train_loss: 0.6874, val_loss: 1.4903, val_acc: 0.6402
# Epoch [42], last_lr: 0.10000, train_loss: 0.6732, val_loss: 1.5477, val_acc: 0.6306
# Epoch [43], last_lr: 0.10000, train_loss: 0.6733, val_loss: 1.4135, val_acc: 0.6359
# Epoch [44], last_lr: 0.10000, train_loss: 0.6616, val_loss: 1.5331, val_acc: 0.6253
# Epoch [45], last_lr: 0.10000, train_loss: 0.6624, val_loss: 1.7441, val_acc: 0.5938
# Epoch [46], last_lr: 0.10000, train_loss: 0.6521, val_loss: 1.5199, val_acc: 0.6281
# Epoch [47], last_lr: 0.10000, train_loss: 0.6380, val_loss: 1.5334, val_acc: 0.6304
# Epoch [48], last_lr: 0.10000, train_loss: 0.6458, val_loss: 1.3529, val_acc: 0.6513
# Epoch [49], last_lr: 0.10000, train_loss: 0.6306, val_loss: 1.6531, val_acc: 0.6156
# Epoch [50], last_lr: 0.10000, train_loss: 0.6312, val_loss: 1.4765, val_acc: 0.6352
# Epoch [51], last_lr: 0.10000, train_loss: 0.6155, val_loss: 1.5571, val_acc: 0.6282
# Epoch [52], last_lr: 0.10000, train_loss: 0.6154, val_loss: 1.5682, val_acc: 0.6255
# Epoch [53], last_lr: 0.10000, train_loss: 0.6095, val_loss: 1.5343, val_acc: 0.6284
# Epoch [54], last_lr: 0.10000, train_loss: 0.5991, val_loss: 1.5403, val_acc: 0.6252
# Epoch [55], last_lr: 0.10000, train_loss: 0.6024, val_loss: 1.4519, val_acc: 0.6370
# Epoch [56], last_lr: 0.10000, train_loss: 0.5935, val_loss: 1.5838, val_acc: 0.6384
# Epoch [57], last_lr: 0.10000, train_loss: 0.5939, val_loss: 1.7372, val_acc: 0.6184
# Epoch [58], last_lr: 0.10000, train_loss: 0.5898, val_loss: 1.4736, val_acc: 0.6392
# Epoch [59], last_lr: 0.10000, train_loss: 0.5741, val_loss: 1.5860, val_acc: 0.6262
# Epoch [60], last_lr: 0.10000, train_loss: 0.5690, val_loss: 1.4735, val_acc: 0.6484
# Epoch [61], last_lr: 0.10000, train_loss: 0.5859, val_loss: 1.3634, val_acc: 0.6585
# Epoch [62], last_lr: 0.10000, train_loss: 0.5570, val_loss: 1.6348, val_acc: 0.6241
# Epoch [63], last_lr: 0.10000, train_loss: 0.5629, val_loss: 1.3890, val_acc: 0.6637
# Epoch [64], last_lr: 0.10000, train_loss: 0.5566, val_loss: 1.5785, val_acc: 0.6304
# Epoch [65], last_lr: 0.10000, train_loss: 0.5574, val_loss: 1.3841, val_acc: 0.6612
# Epoch [66], last_lr: 0.10000, train_loss: 0.5483, val_loss: 1.5054, val_acc: 0.6474
# Epoch [67], last_lr: 0.10000, train_loss: 0.5466, val_loss: 1.6279, val_acc: 0.6124
# Epoch [68], last_lr: 0.10000, train_loss: 0.5480, val_loss: 1.5951, val_acc: 0.6361
# Epoch [69], last_lr: 0.10000, train_loss: 0.5378, val_loss: 1.4677, val_acc: 0.6483
# Epoch [70], last_lr: 0.10000, train_loss: 0.5413, val_loss: 1.5160, val_acc: 0.6446
# Epoch [71], last_lr: 0.10000, train_loss: 0.5352, val_loss: 1.6296, val_acc: 0.6250
# Epoch [72], last_lr: 0.10000, train_loss: 0.5199, val_loss: 1.5062, val_acc: 0.6438
# Epoch [73], last_lr: 0.10000, train_loss: 0.5250, val_loss: 1.6296, val_acc: 0.6286
# Epoch [74], last_lr: 0.10000, train_loss: 0.5268, val_loss: 1.5406, val_acc: 0.6518
# Epoch [75], last_lr: 0.01000, train_loss: 0.2630, val_loss: 1.0056, val_acc: 0.7406
# Epoch [76], last_lr: 0.01000, train_loss: 0.1843, val_loss: 1.0102, val_acc: 0.7456
# Epoch [77], last_lr: 0.01000, train_loss: 0.1563, val_loss: 1.0069, val_acc: 0.7452
# Epoch [78], last_lr: 0.01000, train_loss: 0.1366, val_loss: 1.0228, val_acc: 0.7458
# Epoch [79], last_lr: 0.01000, train_loss: 0.1276, val_loss: 1.0201, val_acc: 0.7503
# Epoch [80], last_lr: 0.01000, train_loss: 0.1160, val_loss: 1.0426, val_acc: 0.7473
# Epoch [81], last_lr: 0.01000, train_loss: 0.1076, val_loss: 1.0436, val_acc: 0.7487
# Epoch [82], last_lr: 0.01000, train_loss: 0.1007, val_loss: 1.0448, val_acc: 0.7500
# Epoch [83], last_lr: 0.01000, train_loss: 0.0933, val_loss: 1.0633, val_acc: 0.7452
# Epoch [84], last_lr: 0.01000, train_loss: 0.0885, val_loss: 1.0700, val_acc: 0.7487
# Epoch [85], last_lr: 0.01000, train_loss: 0.0843, val_loss: 1.0777, val_acc: 0.7481
# Epoch [86], last_lr: 0.01000, train_loss: 0.0794, val_loss: 1.0802, val_acc: 0.7470
# Epoch [87], last_lr: 0.01000, train_loss: 0.0756, val_loss: 1.0884, val_acc: 0.7482
# Epoch [88], last_lr: 0.01000, train_loss: 0.0716, val_loss: 1.0957, val_acc: 0.7498
# Epoch [89], last_lr: 0.01000, train_loss: 0.0681, val_loss: 1.1103, val_acc: 0.7482
# Epoch [90], last_lr: 0.01000, train_loss: 0.0662, val_loss: 1.1056, val_acc: 0.7487
# Epoch [91], last_lr: 0.01000, train_loss: 0.0634, val_loss: 1.1223, val_acc: 0.7477
# Epoch [92], last_lr: 0.01000, train_loss: 0.0601, val_loss: 1.1200, val_acc: 0.7474
# Epoch [93], last_lr: 0.01000, train_loss: 0.0574, val_loss: 1.1265, val_acc: 0.7485
# Epoch [94], last_lr: 0.01000, train_loss: 0.0557, val_loss: 1.1315, val_acc: 0.7476
# Epoch [95], last_lr: 0.01000, train_loss: 0.0549, val_loss: 1.1359, val_acc: 0.7494
# Epoch [96], last_lr: 0.01000, train_loss: 0.0515, val_loss: 1.1469, val_acc: 0.7450
# Epoch [97], last_lr: 0.01000, train_loss: 0.0506, val_loss: 1.1511, val_acc: 0.7443
# Epoch [98], last_lr: 0.01000, train_loss: 0.0496, val_loss: 1.1599, val_acc: 0.7410
# Epoch [99], last_lr: 0.01000, train_loss: 0.0468, val_loss: 1.1476, val_acc: 0.7462
# Epoch [100], last_lr: 0.01000, train_loss: 0.0456, val_loss: 1.1524, val_acc: 0.7456
# Epoch [101], last_lr: 0.01000, train_loss: 0.0448, val_loss: 1.1697, val_acc: 0.7433
# Epoch [102], last_lr: 0.01000, train_loss: 0.0431, val_loss: 1.1650, val_acc: 0.7457
# Epoch [103], last_lr: 0.01000, train_loss: 0.0412, val_loss: 1.1688, val_acc: 0.7429
# Epoch [104], last_lr: 0.01000, train_loss: 0.0405, val_loss: 1.1769, val_acc: 0.7452
# Epoch [105], last_lr: 0.01000, train_loss: 0.0387, val_loss: 1.1758, val_acc: 0.7457
# Epoch [106], last_lr: 0.01000, train_loss: 0.0383, val_loss: 1.1871, val_acc: 0.7419
# Epoch [107], last_lr: 0.01000, train_loss: 0.0381, val_loss: 1.1795, val_acc: 0.7433
# Epoch [108], last_lr: 0.01000, train_loss: 0.0368, val_loss: 1.1883, val_acc: 0.7429
# Epoch [109], last_lr: 0.01000, train_loss: 0.0359, val_loss: 1.1814, val_acc: 0.7450
# Epoch [110], last_lr: 0.01000, train_loss: 0.0350, val_loss: 1.1909, val_acc: 0.7458
# Epoch [111], last_lr: 0.01000, train_loss: 0.0343, val_loss: 1.1840, val_acc: 0.7446
# Epoch [112], last_lr: 0.00100, train_loss: 0.0312, val_loss: 1.1843, val_acc: 0.7450
# Epoch [113], last_lr: 0.00100, train_loss: 0.0300, val_loss: 1.1853, val_acc: 0.7458
# Epoch [114], last_lr: 0.00100, train_loss: 0.0298, val_loss: 1.1836, val_acc: 0.7456
# Epoch [115], last_lr: 0.00100, train_loss: 0.0298, val_loss: 1.1861, val_acc: 0.7464
# Epoch [116], last_lr: 0.00100, train_loss: 0.0295, val_loss: 1.1865, val_acc: 0.7474
# Epoch [117], last_lr: 0.00100, train_loss: 0.0291, val_loss: 1.1867, val_acc: 0.7446
# Epoch [118], last_lr: 0.00100, train_loss: 0.0287, val_loss: 1.1828, val_acc: 0.7461
# Epoch [119], last_lr: 0.00100, train_loss: 0.0282, val_loss: 1.1807, val_acc: 0.7460
# Epoch [120], last_lr: 0.00100, train_loss: 0.0285, val_loss: 1.1908, val_acc: 0.7448
# Epoch [121], last_lr: 0.00100, train_loss: 0.0283, val_loss: 1.1909, val_acc: 0.7473
# Epoch [122], last_lr: 0.00100, train_loss: 0.0279, val_loss: 1.1902, val_acc: 0.7471
# Epoch [123], last_lr: 0.00100, train_loss: 0.0280, val_loss: 1.1823, val_acc: 0.7458
# Epoch [124], last_lr: 0.00100, train_loss: 0.0275, val_loss: 1.1884, val_acc: 0.7468
# Epoch [125], last_lr: 0.00100, train_loss: 0.0285, val_loss: 1.1894, val_acc: 0.7464
# Epoch [126], last_lr: 0.00100, train_loss: 0.0269, val_loss: 1.1867, val_acc: 0.7471
# Epoch [127], last_lr: 0.00100, train_loss: 0.0271, val_loss: 1.1905, val_acc: 0.7476
# Epoch [128], last_lr: 0.00100, train_loss: 0.0271, val_loss: 1.1855, val_acc: 0.7483
# Epoch [129], last_lr: 0.00100, train_loss: 0.0276, val_loss: 1.1981, val_acc: 0.7458
# Epoch [130], last_lr: 0.00100, train_loss: 0.0278, val_loss: 1.1889, val_acc: 0.7452
# Epoch [131], last_lr: 0.00100, train_loss: 0.0272, val_loss: 1.1921, val_acc: 0.7469
# Epoch [132], last_lr: 0.00100, train_loss: 0.0266, val_loss: 1.1942, val_acc: 0.7455
# Epoch [133], last_lr: 0.00100, train_loss: 0.0266, val_loss: 1.1899, val_acc: 0.7459
# Epoch [134], last_lr: 0.00100, train_loss: 0.0262, val_loss: 1.1992, val_acc: 0.7447
# Epoch [135], last_lr: 0.00100, train_loss: 0.0270, val_loss: 1.1884, val_acc: 0.7455
# Epoch [136], last_lr: 0.00100, train_loss: 0.0266, val_loss: 1.1961, val_acc: 0.7442
# Epoch [137], last_lr: 0.00100, train_loss: 0.0258, val_loss: 1.1928, val_acc: 0.7447
# Epoch [138], last_lr: 0.00100, train_loss: 0.0264, val_loss: 1.1909, val_acc: 0.7462
# Epoch [139], last_lr: 0.00100, train_loss: 0.0270, val_loss: 1.1947, val_acc: 0.7449
# Epoch [140], last_lr: 0.00100, train_loss: 0.0259, val_loss: 1.1906, val_acc: 0.7461
# Epoch [141], last_lr: 0.00100, train_loss: 0.0263, val_loss: 1.1896, val_acc: 0.7436
# Epoch [142], last_lr: 0.00100, train_loss: 0.0263, val_loss: 1.1893, val_acc: 0.7465
# Epoch [143], last_lr: 0.00100, train_loss: 0.0254, val_loss: 1.1899, val_acc: 0.7444
# Epoch [144], last_lr: 0.00100, train_loss: 0.0261, val_loss: 1.1904, val_acc: 0.7455
# Epoch [145], last_lr: 0.00100, train_loss: 0.0260, val_loss: 1.1975, val_acc: 0.7446
# Epoch [146], last_lr: 0.00100, train_loss: 0.0249, val_loss: 1.1961, val_acc: 0.7456
# Epoch [147], last_lr: 0.00100, train_loss: 0.0252, val_loss: 1.1975, val_acc: 0.7465
# Epoch [148], last_lr: 0.00100, train_loss: 0.0258, val_loss: 1.1974, val_acc: 0.7433
# Epoch [149], last_lr: 0.00100, train_loss: 0.0253, val_loss: 1.1956, val_acc: 0.7454

# %%
def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history], "-bx")
    plt.plot([x["val_loss"] for x in history],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","test loss"])
    plt.title('None process Loss')
    plt.show()

def plot_testAcc(history):
    plt.plot([x.get("val_acc") for x in history], "-bx")
    plt.xlabel("Epoch")
    plt.ylabel("acc")
    plt.legend(["test Acc"])
    plt.title('None process Test Acc')
    plt.show()

plot_loss(history_none)
plot_testAcc(history_none)
